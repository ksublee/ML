# %%
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt 

import numpy as np

raw_wine = datasets.load_wine()
X = raw_wine["data"]
y = raw_wine.target

Cs = np.concatenate([
    np.logspace(-4, -2, 5),  # 0.0001 ~ 0.01
    np.linspace(0.01, 0.1, 5),  # 0.01 ~ 0.1
    np.linspace(0.1, 1.5, 10),  # 0.1 ~ 1.5
    np.linspace(11, 20, 10)
])
L_errs = []

for C in Cs:
    
    pipe = make_pipeline(
        StandardScaler(),
        LogisticRegression(multi_class="multinomial", max_iter=5000, C=C)
    )
    
    lr_scores = cross_val_score(pipe, X, y, cv=5)
    L_errs.append((1-lr_scores).mean())

min_idx = np.argmin(L_errs)
min_C = Cs[min_idx]
min_err = L_errs[min_idx]

plt.figure(figsize=(8, 6))

ax = plt.gca()
ax.plot(min_C, min_err, 'ro', label=f"Min error: {min_err:.4f} at C={min_C}")
ax.legend()

ax.plot(Cs, L_errs)
ax.set_xscale("log")
plt.title("The error as a function of the regularization parameter")
plt.axis("tight")
plt.show()

# %%
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt 

import numpy as np

raw_wine = datasets.load_wine()
X = raw_wine["data"]
y = raw_wine.target

Cs = np.concatenate([
    np.logspace(-4, -2, 5),  # 0.0001 ~ 0.01
    np.linspace(0.01, 0.1, 5),  # 0.01 ~ 0.1
    np.linspace(0.1, 1.5, 10),  # 0.1 ~ 1.5
    np.linspace(11, 20, 10)
])
L_errs = []

for C in Cs:
    
    pipe = make_pipeline(
       
        LogisticRegression(multi_class="multinomial", max_iter=5000, C=C)
    )
    
    lr_scores = cross_val_score(pipe, X, y, cv=5)
    L_errs.append((1-lr_scores).mean())

min_idx = np.argmin(L_errs)
min_C = Cs[min_idx]
min_err = L_errs[min_idx]

plt.figure(figsize=(8, 6))

ax = plt.gca()
ax.plot(min_C, min_err, 'ro', label=f"Min error: {min_err:.4f} at C={min_C}")
ax.legend()

ax.plot(Cs, L_errs)
ax.set_xscale("log")
plt.title("The error as a function of the regularization parameter")
plt.axis("tight")
plt.show()
# Out:
# C:\Users\Owner\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Owner\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
# 최적 C로 전체 데이터를 이용해 다시 학습
best_pipe = make_pipeline(
    StandardScaler(),
    LogisticRegression(multi_class="multinomial", max_iter=5000, C=min_C)
)
best_pipe.fit(X, y)

# 계수 추출
# 파이프라인에서 LogisticRegression 객체를 꺼냄
logreg = best_pipe.named_steps["logisticregression"]

# 클래스별 계수 (shape: [n_classes, n_features])
coefs = logreg.coef_

# 절편
intercepts = logreg.intercept_

# 예시 출력
print("계수 shape:", coefs.shape)
print("클래스별 계수:\n", coefs)
print("클래스별 절편:\n", intercepts)
# Out:
# 계수 shape: (3, 13)
# 클래스별 계수:
#  [[ 0.71021123  0.15787887  0.40922686 -0.7283609   0.04439655  0.22560666
#    0.55676533 -0.18913776  0.11614662  0.14273683  0.1246248   0.62362331
#    0.93708681]
#  [-0.89667623 -0.39326951 -0.70805002  0.48795447 -0.1099653   0.03267827
#    0.28172585  0.16481607  0.23821541 -0.8779274   0.57781033  0.05776645
#   -0.96896688]
#  [ 0.186465    0.23539064  0.29882316  0.24040644  0.06556875 -0.25828493
#   -0.83849118  0.02432169 -0.35436203  0.73519056 -0.70243514 -0.68138976
#    0.03188007]]
# 클래스별 절편:
#  [ 0.31741851  0.65540323 -0.97282174]

# %%
basic_pipe = make_pipeline(
    StandardScaler(),
    LogisticRegression(multi_class="multinomial", max_iter=5000)
)
basic_pipe.fit(X, y)

# 계수 추출
# 파이프라인에서 LogisticRegression 객체를 꺼냄
basic_logreg = basic_pipe.named_steps["logisticregression"]

# 클래스별 계수 (shape: [n_classes, n_features])
coefs = basic_logreg.coef_

# 절편
intercepts = basic_logreg.intercept_

# 예시 출력
print("계수 shape:", coefs.shape)
print("클래스별 계수:\n", coefs)
print("클래스별 절편:\n", intercepts)
# Out:
# 계수 shape: (3, 13)
# 클래스별 계수:
#  [[ 0.81013479  0.20382073  0.47221242 -0.84478439  0.04952905  0.2137248
#    0.64787507 -0.19982499  0.13833868  0.17160966  0.13090887  0.72595069
#    1.07895949]
#  [-1.01032338 -0.44045953 -0.848074    0.58357323 -0.09770602  0.02752798
#    0.35399157  0.21278279  0.26336105 -1.04127077  0.6825216   0.05287635
#   -1.14079293]
#  [ 0.20018858  0.2366388   0.37586158  0.26121116  0.04817698 -0.24125278
#   -1.00186664 -0.0129578  -0.40169973  0.86966111 -0.81343047 -0.77882704
#    0.06183345]]
# 클래스별 절편:
#  [ 0.41229358  0.70481641 -1.11711   ]

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons

X, y = make_moons(n_samples=200, noise=0.2)

plt.scatter(X[y == 0, 0], X[y == 0, 1], color='r', marker='o', label='Class 0')
plt.scatter(X[y == 1, 0], X[y == 1, 1], color='b', marker='^', label='Class 1')
plt.legend()
plt.show()
